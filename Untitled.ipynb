# %%
import matplotlib.pyplot as plt
plt.xlabel('step')
plt.ylabel('Runtime (ms)')
plt.plot([1,5000001,10000001,15000001,20000001,30000001,40000001,50000001,60000001,70000001,
          80000001,90000001,100000001,110000001,120000001,130000001,134000001], 
         [302,327,290,312,371,416,440,420,550,401,363,390,445,493,525,561,577], 'r-', label='O0')

plt.plot([1,5000001,10000001,15000001,20000001,30000001,40000001,50000001,60000001,70000001,
          80000001,90000001,100000001,110000001,120000001,130000001,134000001],
         [59,49,53,54,63,86,72,75,86,69,81,88,104,106,137,154,246], 'b-',label='O1')

plt.plot([1,5000001,10000001,15000001,20000001,30000001,40000001,50000001,60000001,70000001,
          80000001,90000001,100000001,110000001,120000001,130000001,134000001],
         [41,142,142,97,101,109,105,129,229,136,145,161,179,205,218,254,263], 'g-', label='O2')

plt.plot([1,5000001,10000001,15000001,20000001,30000001,40000001,50000001,60000001,70000001,
          80000001,90000001,100000001,110000001,120000001,130000001,134000001],
         [48,165,101,97,134,86,118,106,142,147,250,148,182,193,234,251,245], 'm-', label='O3')
plt.axis([0, 135000000, 0, 600])
plt.title('N = X')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.xlabel('step')
plt.ylabel('Runtime (ms)')
plt.plot([1, 1000001, 2000001, 3000001, 4000001, 5000001, 6000001, 7000001, 8000001, 9000001], 
         [290, 261, 264, 321, 323, 279, 335, 390, 448, 503], 'r-', label='O0')

plt.plot([1, 1000001, 2000001, 3000001, 4000001, 5000001, 6000001, 7000001, 8000001, 9000001],
         [58, 59, 73, 75, 80, 70, 82, 93, 102, 118], 'b-',label='O1')

plt.plot([1, 1000001, 2000001, 3000001, 4000001, 5000001, 6000001, 7000001, 8000001, 9000001],
         [32, 59, 58, 75, 82, 83, 100, 114, 133, 150], 'g-', label='O2')

plt.plot([1, 1000001, 2000001, 3000001, 4000001, 5000001, 6000001, 7000001, 8000001, 9000001],
         [31, 58, 57, 75, 81, 81, 98, 112, 128, 144], 'm-', label='O3')
plt.axis([0, 9000001, 0, 600])
plt.title('N = 10,000,000')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.xlabel('step')
plt.ylabel('Runtime (ms)')
plt.plot([1, 5000001, 10000001, 15000001, 20000001, 25000001, 30000001, 35000001, 40000001, 45000001], 
         [224, 204, 205, 248, 252, 215, 258, 300, 382, 431], 'r-', label='O0')

plt.plot([1, 5000001, 10000001, 15000001, 20000001, 25000001, 30000001, 35000001, 40000001, 45000001],
         [55, 45, 54, 58, 62, 47, 71, 79, 87, 104], 'b-',label='O1')

plt.plot([1, 5000001, 10000001, 15000001, 20000001, 25000001, 30000001, 35000001, 40000001, 45000001],
         [34, 47, 45, 60, 61, 61, 73, 85, 116, 122], 'g-', label='O2')

plt.plot([1, 5000001, 10000001, 15000001, 20000001, 25000001, 30000001, 35000001, 40000001, 45000001],
         [33, 47, 43, 57, 61, 63, 73, 85, 98, 111], 'm-', label='O3')
plt.axis([0, 45000001, 0, 500])
plt.title('N = 50,000,000')
plt.legend()
plt.show()
